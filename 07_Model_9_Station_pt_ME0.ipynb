# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, normalize
from sklearn.metrics import mean_squared_error

# %%
# configure plots
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 6, 4

# %% [markdown]
# # Data

# %% [markdown]
# ## Raw Data

# %%
X = pd.read_csv('./9_Station_ME0/X.csv', index_col=0)
y = pd.read_csv('./9_Station_ME0/y.csv', index_col=0)

# %% [markdown]
# ## Fill NaN

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))
y_standard = scaler.fit_transform(pd.DataFrame(y['pt']))
y_standard = pd.DataFrame(y_standard, columns=['pt_s'], index=y.index)
y['pt_s'] = y_standard['pt_s']

# %%
X = X.fillna(0)

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 1)

# %% [markdown]
# # Visualize Baseline Model

# %%
visual = y_test.reset_index()

# %%
visual['pt_pred'] = scaler.inverse_transform(pd.DataFrame(y_pred))

# %%
visual['delta_1/pt'] = 1/visual['pt'] - 1/visual['pt_pred']

# %%
fig, ax = plt.subplots()
line = [0, 100]
ax.plot(line, line)
ax.scatter(visual['pt'], 
           visual['pt_pred'], 
#            c = visual['eta_median'], 
           cmap = 'copper', 
           s = 2, alpha = 1)
plt.ylim(0, 100)
ax.grid(True)

# %% [markdown]
# ## Bias and Resolution

# %%
points = range(2, 100)
bias = []
resolution = []

# %%
for i in points:
    temp = visual[(visual['pt']>i) & (visual['pt']<i+1)]
    bias.append(temp['delta_1/pt'].mean())
    resolution.append(temp['delta_1/pt'].std())
#     resolution.append((temp['delta_1/pt'].max() - temp['delta_1/pt'].min())/2)

# %%
fig, ax = plt.subplots()
ax.errorbar(points, bias, color='firebrick', yerr=resolution, errorevery=2)
plt.ylim(-0.1, 0.2)
ax.set(xlabel=r'gen $p_t$ [GeV]', ylabel=r' $\Delta(p_t)/p_t$ bias')
ax.grid(True)
# ax.set_title('all errorbars')
fig.savefig('9s_me0.jpg', format='jpg', dpi=900)

# %% [markdown]
# # NN

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
# Out:
# Using TensorFlow backend.

# %%
X.shape
# Out:
# (110779, 57)

# %%
# 搭建模型
def create_model():
    classifier = Sequential()
    # 输入层及第一个隐藏层
    classifier.add(Dense(activation="tanh", 
                         input_dim=57, 
                         units=80, 
                         kernel_initializer="uniform"))
    # 第二个隐藏层
    classifier.add(Dense(activation="tanh", 
                         units=50, 
                         kernel_initializer="uniform"))
    # 第三个隐藏层
    classifier.add(Dense(activation="tanh", 
                         units=30, 
                         kernel_initializer="uniform"))
    # 输出层
    classifier.add(Dense(activation="tanh", 
                         units=1, 
                         kernel_initializer="uniform"))
    
    classifier.compile(optimizer = 'adam', 
                       loss = 'mse', 
                       metrics = ['mse'])
    return classifier

model = KerasRegressor(build_fn=create_model)

# %%
model.fit(X_train,
          y_train['pt_s'], 
          validation_data = (X_test, y_test['pt_s']),
          batch_size=5, 
          epochs = 20)
# Out:
# Train on 88623 samples, validate on 22156 samples
# Epoch 1/20
# 88623/88623 [==============================] - 36s 409us/step - loss: 0.3307 - mean_squared_error: 0.3307 - val_loss: 0.3314 - val_mean_squared_error: 0.3314
# Epoch 2/20
# 88623/88623 [==============================] - 33s 371us/step - loss: 0.2760 - mean_squared_error: 0.2760 - val_loss: 0.2196 - val_mean_squared_error: 0.2196
# Epoch 3/20
# 88623/88623 [==============================] - 30s 342us/step - loss: 0.1888 - mean_squared_error: 0.1888 - val_loss: 0.1599 - val_mean_squared_error: 0.1599
# Epoch 4/20
# 88623/88623 [==============================] - 31s 345us/step - loss: 0.1565 - mean_squared_error: 0.1565 - val_loss: 0.1292 - val_mean_squared_error: 0.1292
# Epoch 5/20
# 88623/88623 [==============================] - 31s 345us/step - loss: 0.1388 - mean_squared_error: 0.1388 - val_loss: 0.1353 - val_mean_squared_error: 0.1353
# Epoch 6/20
# 88623/88623 [==============================] - 32s 364us/step - loss: 0.1322 - mean_squared_error: 0.1322 - val_loss: 0.1384 - val_mean_squared_error: 0.1384
# Epoch 7/20
# 88623/88623 [==============================] - 31s 352us/step - loss: 0.1280 - mean_squared_error: 0.1280 - val_loss: 0.1324 - val_mean_squared_error: 0.1324
# Epoch 8/20
# 88623/88623 [==============================] - 31s 346us/step - loss: 0.1259 - mean_squared_error: 0.1259 - val_loss: 0.1139 - val_mean_squared_error: 0.1139
# Epoch 9/20
# 88623/88623 [==============================] - 30s 340us/step - loss: 0.1237 - mean_squared_error: 0.1237 - val_loss: 0.1306 - val_mean_squared_error: 0.1306
# Epoch 10/20
# 88623/88623 [==============================] - 30s 339us/step - loss: 0.1230 - mean_squared_error: 0.1230 - val_loss: 0.1137 - val_mean_squared_error: 0.1137
# Epoch 11/20
# 88623/88623 [==============================] - 30s 342us/step - loss: 0.1200 - mean_squared_error: 0.1200 - val_loss: 0.1189 - val_mean_squared_error: 0.1189
# Epoch 12/20
# 88623/88623 [==============================] - 34s 378us/step - loss: 0.1179 - mean_squared_error: 0.1179 - val_loss: 0.1154 - val_mean_squared_error: 0.1154
# Epoch 13/20
# 88623/88623 [==============================] - 31s 354us/step - loss: 0.1178 - mean_squared_error: 0.1178 - val_loss: 0.1141 - val_mean_squared_error: 0.1141
# Epoch 14/20
# 88623/88623 [==============================] - 33s 374us/step - loss: 0.1160 - mean_squared_error: 0.1160 - val_loss: 0.1305 - val_mean_squared_error: 0.1305
# Epoch 15/20
# 88623/88623 [==============================] - 32s 365us/step - loss: 0.1146 - mean_squared_error: 0.1146 - val_loss: 0.1103 - val_mean_squared_error: 0.1103
# Epoch 16/20
# 88623/88623 [==============================] - 32s 363us/step - loss: 0.1137 - mean_squared_error: 0.1137 - val_loss: 0.1268 - val_mean_squared_error: 0.1268
# Epoch 17/20
# 88623/88623 [==============================] - 33s 370us/step - loss: 0.1129 - mean_squared_error: 0.1129 - val_loss: 0.1146 - val_mean_squared_error: 0.1146
# Epoch 18/20
# 88623/88623 [==============================] - 32s 364us/step - loss: 0.1106 - mean_squared_error: 0.1106 - val_loss: 0.1151 - val_mean_squared_error: 0.1151
# Epoch 19/20
# 88623/88623 [==============================] - 32s 359us/step - loss: 0.1110 - mean_squared_error: 0.1110 - val_loss: 0.1061 - val_mean_squared_error: 0.1061
# Epoch 20/20
# 88623/88623 [==============================] - 33s 370us/step - loss: 0.1094 - mean_squared_error: 0.1094 - val_loss: 0.1185 - val_mean_squared_error: 0.1185

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# # Save Results

# %%
visual.to_csv('result_9s_me0_run1.csv')

# %% [markdown]
# Run 1: predict pt, epoch 20, batch 5, mse, tanh
