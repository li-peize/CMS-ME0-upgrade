# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, normalize
from sklearn.metrics import mean_squared_error

# %%
# configure plots
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 6, 4

# %% [markdown]
# # Data

# %% [markdown]
# ## Raw Data

# %%
X = pd.read_csv('./8_Station/X.csv', index_col=0)
y = pd.read_csv('./8_Station/y.csv', index_col=0)

# %% [markdown]
# ## Fill NaN

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))
y_standard = scaler.fit_transform(pd.DataFrame(y['pt']))
y_standard = pd.DataFrame(y_standard, columns=['pt_s'], index=y.index)
y['pt_s'] = y_standard['pt_s']

# %%
X = X.fillna(0)

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 1)

# %% [markdown]
# # Visualize Baseline Model

# %%
visual = y_test.reset_index()

# %%
visual['pt_pred'] = scaler.inverse_transform(pd.DataFrame(y_pred))

# %%
visual['delta_1/pt'] = 1/visual['pt'] - 1/visual['pt_pred']

# %%
fig, ax = plt.subplots()
line = [0, 100]
ax.plot(line, line)
ax.scatter(visual['pt'], 
           visual['pt_pred'], 
           c = visual['eta_median'], 
           cmap = 'copper', 
           s = 2, 
           alpha = 1)
plt.ylim(0, 100)
ax.grid(True)

# %% [markdown]
# ## Bias and Resolution

# %%
points = range(2, 100)
bias = []
resolution = []

# %%
for i in points:
    temp = visual[(visual['pt']>i) & (visual['pt']<i+1)]
    bias.append(temp['delta_1/pt'].mean())
    resolution.append(temp['delta_1/pt'].std())
#     resolution.append((temp['delta_1/pt'].max() - temp['delta_1/pt'].min())/2)

# %%
fig, ax = plt.subplots()
ax.errorbar(points, bias, color='firebrick', yerr=resolution, errorevery=2)
plt.ylim(-0.1, 0.2)
ax.set(xlabel=r'gen $p_t$ [GeV]', ylabel=r' $\Delta(p_t)/p_t$ bias')
ax.grid(True)
# ax.set_title('all errorbars')
fig.savefig('8s.jpg', format='jpg', dpi=900)

# %% [markdown]
# # NN

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
# Out:
# Using TensorFlow backend.

# %%
X.shape
# Out:
# (138011, 51)

# %%
# 搭建模型
def create_model():
    classifier = Sequential()
    # 输入层及第一个隐藏层
    classifier.add(Dense(activation="tanh", 
                         input_dim=51, 
                         units=80, 
                         kernel_initializer="uniform"))
    # 第二个隐藏层
    classifier.add(Dense(activation="tanh", 
                         units=50, 
                         kernel_initializer="uniform"))
    # 第三个隐藏层
    classifier.add(Dense(activation="tanh", 
                         units=30, 
                         kernel_initializer="uniform"))
    # 输出层
    classifier.add(Dense(activation="tanh", 
                         units=1, 
                         kernel_initializer="uniform"))
    
    classifier.compile(optimizer = 'adam', 
                       loss = 'mse', 
                       metrics = ['mse'])
    return classifier

model = KerasRegressor(build_fn=create_model)

# %%
model.fit(X_train,
          y_train['pt_s'], 
          validation_data = (X_test, y_test['pt_s']),
          batch_size=5, 
          epochs = 20)
# Out:
# Train on 110408 samples, validate on 27603 samples
# Epoch 1/20
# 110408/110408 [==============================] - 40s 365us/step - loss: 0.3077 - mean_squared_error: 0.3077 - val_loss: 0.2936 - val_mean_squared_error: 0.2936
# Epoch 2/20
# 110408/110408 [==============================] - 38s 343us/step - loss: 0.2543 - mean_squared_error: 0.2543 - val_loss: 0.1927 - val_mean_squared_error: 0.1927
# Epoch 3/20
# 110408/110408 [==============================] - 37s 337us/step - loss: 0.1891 - mean_squared_error: 0.1891 - val_loss: 0.1710 - val_mean_squared_error: 0.1710
# Epoch 4/20
# 110408/110408 [==============================] - 38s 342us/step - loss: 0.1750 - mean_squared_error: 0.1750 - val_loss: 0.1639 - val_mean_squared_error: 0.1639
# Epoch 5/20
# 110408/110408 [==============================] - 37s 338us/step - loss: 0.1566 - mean_squared_error: 0.1566 - val_loss: 0.1413 - val_mean_squared_error: 0.1413
# Epoch 6/20
# 110408/110408 [==============================] - 38s 340us/step - loss: 0.1452 - mean_squared_error: 0.1452 - val_loss: 0.1364 - val_mean_squared_error: 0.1364
# Epoch 7/20
# 110408/110408 [==============================] - 38s 340us/step - loss: 0.1406 - mean_squared_error: 0.1406 - val_loss: 0.1422 - val_mean_squared_error: 0.1422
# Epoch 8/20
# 110408/110408 [==============================] - 38s 341us/step - loss: 0.1391 - mean_squared_error: 0.1391 - val_loss: 0.1359 - val_mean_squared_error: 0.1359
# Epoch 9/20
# 110408/110408 [==============================] - 38s 342us/step - loss: 0.1381 - mean_squared_error: 0.1381 - val_loss: 0.1356 - val_mean_squared_error: 0.1356
# Epoch 10/20
# 110408/110408 [==============================] - 38s 343us/step - loss: 0.1357 - mean_squared_error: 0.1357 - val_loss: 0.1477 - val_mean_squared_error: 0.1477
# Epoch 11/20
# 110408/110408 [==============================] - 38s 343us/step - loss: 0.1343 - mean_squared_error: 0.1343 - val_loss: 0.1413 - val_mean_squared_error: 0.1413
# Epoch 12/20
# 110408/110408 [==============================] - 38s 345us/step - loss: 0.1322 - mean_squared_error: 0.1322 - val_loss: 0.1304 - val_mean_squared_error: 0.1304
# Epoch 13/20
# 110408/110408 [==============================] - 38s 344us/step - loss: 0.1315 - mean_squared_error: 0.1315 - val_loss: 0.1309 - val_mean_squared_error: 0.1309
# Epoch 14/20
# 110408/110408 [==============================] - 38s 344us/step - loss: 0.1313 - mean_squared_error: 0.1313 - val_loss: 0.1307 - val_mean_squared_error: 0.1307
# Epoch 15/20
# 110408/110408 [==============================] - 38s 343us/step - loss: 0.1298 - mean_squared_error: 0.1298 - val_loss: 0.1304 - val_mean_squared_error: 0.1304
# Epoch 16/20
# 110408/110408 [==============================] - 40s 363us/step - loss: 0.1291 - mean_squared_error: 0.1291 - val_loss: 0.1564 - val_mean_squared_error: 0.1564
# Epoch 17/20
# 110408/110408 [==============================] - 41s 372us/step - loss: 0.1295 - mean_squared_error: 0.1295 - val_loss: 0.1279 - val_mean_squared_error: 0.1279
# Epoch 18/20
# 110408/110408 [==============================] - 43s 386us/step - loss: 0.1278 - mean_squared_error: 0.1278 - val_loss: 0.1235 - val_mean_squared_error: 0.1235
# Epoch 19/20
# 110408/110408 [==============================] - 43s 394us/step - loss: 0.1275 - mean_squared_error: 0.1275 - val_loss: 0.1208 - val_mean_squared_error: 0.1208
# Epoch 20/20
# 110408/110408 [==============================] - 45s 411us/step - loss: 0.1276 - mean_squared_error: 0.1276 - val_loss: 0.1385 - val_mean_squared_error: 0.1385

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# # Save Results

# %%
visual.to_csv('result_8_run1.csv')

# %% [markdown]
# Run 1: predict pt, epoch 20, batch 5, mse, tanh
